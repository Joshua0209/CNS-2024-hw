# %% [markdown]
# ## Decrypted Server Private Key

# %%
# !git clone https://github.com/RsaCtfTool/RsaCtfTool.git
# Out:
# Cloning into 'RsaCtfTool'...
# remote: Enumerating objects: 5307, done.
# remote: Counting objects: 100% (791/791), done.
# remote: Compressing objects: 100% (249/249), done.
# remote: Total 5307 (delta 613), reused 622 (delta 540), pack-reused 4516
# Receiving objects: 100% (5307/5307), 20.97 MiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (3694/3694), done.

# %%
# !sudo apt-get install libgmp3-dev libmpc-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgmp-dev libgmpxx4ldbl libmpfr-dev
# Suggested packages:
#   gmp-doc libgmp10-doc libmpfr-doc
# The following NEW packages will be installed:
#   libgmp-dev libgmp3-dev libgmpxx4ldbl libmpc-dev libmpfr-dev
# 0 upgraded, 5 newly installed, 0 to remove and 45 not upgraded.
# Need to get 680 kB of archives.
# After this operation, 3,296 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp3-dev amd64 2:6.2.1+dfsg-3ubuntu1 [1,818 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# ...

# %%
# !pip3 install -r "RsaCtfTool/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 MB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 30.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !python ./RsaCtfTool/RsaCtfTool.py -n ... -e 65537 --private --attack fermat
# Out:
# ['/tmp/tmp2myocv99']
#
# [*] Testing key /tmp/tmp2myocv99.
# [*] Performing fermat attack on /tmp/tmp2myocv99.
# [*] Attack success with fermat method !
#
# Results for /tmp/tmp2myocv99:
#
# Private key :
# -----BEGIN RSA PRIVATE KEY-----
# MIIJJwIBAAKCAgEA3XpMVQzFjs55fT/NPufIaOKOckEPyvb1XZwe8QlKc1p+CunD
# 5XKwZl+2naboVR08NjosithWs43L6tCuC9mSn9m2V7ggD/sWB1yEIUoyGj50fLYY
# X5IMbHbjigUL5Y+p+1zT517FEcSjIeddpjk4pqHPtoDLGCciS51mKXQVQMe62tLc
# NbxFE3RA5ec7aOaTDeQ5xq0GfbpYFsNILQoQjYijiq9VrfeAVlLPLXru3oAKYNs/
# opwIruqYNNF4nXkYBKXS/7KxgrPg87u9IVAxwh7HU9AmPusck3RF36dgVKGGakFD
# vYk/zfs8T8Q77+82ligWeooxszEW5G8KwLM8zatnZTbJ/2Cb+uEf3e+EdPjycCFf
# pEv4uI/3jNfsC/5eH5nMkVbKNR03NpCkeSWSm9i8zzUJVB+zkfHkAyDbJPpL1An9
# RAlBN30nZ4GRt5rm839yFl5180DDDb8Cg8GkI0w8RhYs1I62iR1F/Lq2ILud0Kv0
# dZK4dusYf05DK+2JSyD/HcBYFlKwdSVpnx6D6sB3RyIxZKI0Hcg5QCFxroGI8seC
# DEsI77aapYL/Rr0ToyYpt7fihfe3yE4GEGMQR9QWETo7jQORp5fQLUv/Hd164KRr
# 3vaLE/+HKOyZmAm9I04wNqshlxaQm1TtdaK5LDugOXqVy46ONFPgxcU5Eh8CAwEA
# ...

# %% [markdown]
# ## Create Client Certificate

# %%
with open('private.pem', 'w') as f:
    f.write("""-----BEGIN PRIVATE KEY-----

-----END PRIVATE KEY-----""")
# From decrypted packet

# %%
! openssl req -new -key private.pem -out CA.csr -subj "/C=TW/ST=Taiwan/L=Taipei/O=NTU CNS/OU=ROOT/CN=ROOT/emailAddress=cns@csie.ntu.edu.tw"
! openssl x509 -req -sha256 -days 365 -in CA.csr -signkey private.pem -out CA.crt
! openssl req -x509 -new -nodes -key private.pem -sha256 -days 36500 -out rootCA.crt -subj "/C=TW/ST=Taiwan/L=Taipei/O=NTU CNS/OU=ROOT/CN=ROOT/emailAddress=cns@csie.ntu.edu.tw"

! openssl genrsa -out mykey
! openssl req -new -key mykey -out mykey.csr -subj "/C=TW/ST=Taiwan/L=Taipei/O=NTU CNS/OU=VIP/CN=Alice413/emailAddress=cns@csie.ntu.edu.tw"
! openssl x509 -req -CAcreateserial -days 365 -sha256 -CA rootCA.crt -CAkey private.pem -in mykey.csr -out mykey.crt
# Out:
# Certificate request self-signature ok
# subject=C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = ROOT, CN = ROOT, emailAddress = cns@csie.ntu.edu.tw
# Certificate request self-signature ok
# subject=C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = VIP, CN = Alice413, emailAddress = cns@csie.ntu.edu.tw

# %%
! openssl s_client -connect cns.csie.org:4000 -cert mykey.crt -key mykey
# Out:
# CONNECTED(00000003)
# depth=1 C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = ROOT, CN = ROOT, emailAddress = cns@csie.ntu.edu.tw
# verify error:num=19:self-signed certificate in certificate chain
# verify return:1
# depth=1 C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = ROOT, CN = ROOT, emailAddress = cns@csie.ntu.edu.tw
# verify return:1
# depth=0 C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = TA, CN = CNS, emailAddress = cns@csie.ntu.edu.tw
# verify return:1
# ---
# Certificate chain
#  0 s:C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = TA, CN = CNS, emailAddress = cns@csie.ntu.edu.tw
#    i:C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = ROOT, CN = ROOT, emailAddress = cns@csie.ntu.edu.tw
#    a:PKEY: rsaEncryption, 4096 (bit); sigalg: RSA-SHA256
#    v:NotBefore: Mar 27 02:30:08 2024 GMT; NotAfter: May 26 02:30:08 2024 GMT
#  1 s:C = TW, ST = Taiwan, L = Taipei, O = NTU CNS, OU = ROOT, CN = ROOT, emailAddress = cns@csie.ntu.edu.tw
# ...
