# %% [markdown]
# # setup

# %%
# !git clone https://github.com/RsaCtfTool/RsaCtfTool.git
# Out:
# Cloning into 'RsaCtfTool'...
# remote: Enumerating objects: 5291, done.
# remote: Counting objects: 100% (1142/1142), done.
# remote: Compressing objects: 100% (244/244), done.
# remote: Total 5291 (delta 965), reused 975 (delta 896), pack-reused 4149
# Receiving objects: 100% (5291/5291), 20.94 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (3672/3672), done.

# %%
# !sudo apt-get install libgmp3-dev libmpc-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgmp-dev libgmpxx4ldbl libmpfr-dev
# Suggested packages:
#   gmp-doc libgmp10-doc libmpfr-doc
# The following NEW packages will be installed:
#   libgmp-dev libgmp3-dev libgmpxx4ldbl libmpc-dev libmpfr-dev
# 0 upgraded, 5 newly installed, 0 to remove and 45 not upgraded.
# Need to get 680 kB of archives.
# After this operation, 3,296 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp-dev amd64 2:6.2.1+dfsg-3ubuntu1 [337 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmp3-dev amd64 2:6.2.1+dfsg-3ubuntu1 [1,818 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpfr-dev amd64 4.1.0-3build3 [271 kB]
# ...

# %%
# !pip3 install -r "RsaCtfTool/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 MB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 27.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get install sagemath
# !pip3 install -r "./RsaCtfTool/optional-requirements.txt"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   4ti2 bc cliquer cysignals-tools cython3 default-jre default-jre-headless
#   docutils-common dvisvgm ecl eclib-tools fflas-ffpack fflas-ffpack-common
#   flintqs fltk1.3-doc fluid fonts-dejavu-core fonts-dejavu-extra
#   fonts-droid-fallback fonts-font-awesome fonts-glyphicons-halflings
#   fonts-lato fonts-lmodern fonts-lyx fonts-mathjax fonts-mathjax-extras
#   fonts-noto-mono fonts-texgyre fonts-urw-base35 gap gap-alnuth gap-atlasrep
#   gap-autpgrp gap-character-tables gap-core gap-dev gap-doc gap-factint
#   gap-gapdoc gap-io gap-libs gap-online-help gap-polycyclic gap-primgrp
#   gap-smallgrp gap-table-of-marks gap-transgrp gdb gfan ghostscript glpk-utils
#   gmp-ecm gsfonts imagemagick imagemagick-6-common imagemagick-6.q16
#   javascript-common jmol jupyter-core jupyter-nbextension-jupyter-js-widgets
# ...

# %%
import gmpy2

# %% [markdown]
# # Decrypt

# %%
# !python ./RsaCtfTool/RsaCtfTool.py -h
# Out:
# usage: RsaCtfTool.py [-h] [--publickey PUBLICKEY] [--output OUTPUT] [--timeout TIMEOUT]
#                      [--createpub] [--dumpkey] [--ext] [--decryptfile DECRYPTFILE]
#                      [--decrypt DECRYPT] [--verbosity {CRITICAL,ERROR,WARNING,DEBUG,INFO}]
#                      [--private] [--tests] [--ecmdigits ECMDIGITS] [-n N] [-p P] [-q Q] [-e E]
#                      [-d D] [--key KEY] [--password PASSWORD]
# ...

# %% [markdown]
# ## (a) Affine

# %%
# !python ./RsaCtfTool/RsaCtfTool.py -n 62838888092153740229662509357218645484094205004255271563229397398721312187611 -e 65537 --decrypt 32006680458419540072568880298712512535727701644113800410415230556021990484229
# Out:
# private argument is not set, the private key will not be displayed, even if recovered.
# ['/tmp/tmpfpwh3em4']
#
# [*] Testing key /tmp/tmpfpwh3em4.
# attack initialized...
# attack initialized...
# [*] Performing pastctfprimes attack on /tmp/tmpfpwh3em4.
# [+] Time elapsed: 0.0007 sec.
# [*] Performing smallq attack on /tmp/tmpfpwh3em4.
# [+] Time elapsed: 0.7168 sec.
# [*] Performing lucas_gcd attack on /tmp/tmpfpwh3em4.
# 100% 9999/9999 [00:00<00:00, 128885.96it/s]
# [+] Time elapsed: 0.0854 sec.
# [*] Performing system_primes_gcd attack on /tmp/tmpfpwh3em4.
# 100% 7007/7007 [00:00<00:00, 244401.20it/s]
# [+] Time elapsed: 0.0642 sec.
# [*] Performing fibonacci_gcd attack on /tmp/tmpfpwh3em4.
# 100% 9999/9999 [00:00<00:00, 57903.47it/s]
# [+] Time elapsed: 0.1816 sec.
# [*] Performing nonRSA attack on /tmp/tmpfpwh3em4.
# [+] Time elapsed: 0.0008 sec.
# [*] Performing mersenne_primes attack on /tmp/tmpfpwh3em4.
#  24% 12/51 [00:00<00:00, 179116.19it/s]
# ...

# %% [markdown]
# ## (b) Bob

# %% [markdown]
# ### Create key file

# %%
# !python ./RsaCtfTool/RsaCtfTool.py --createpub -n ... -e 65537 --decrypt ... --private
# Out:
# -----BEGIN PUBLIC KEY-----
# MIICIjANBgkqhkiG9w0BAQEFAAOCAg8AMIICCgKCAgEAznbaCRJdXqZeSYzwPwwi
# RQSQLS5j88sz+Y+UGfi4qYRlHl1kOMM1rM/N7PLbt61eQ1VtiwTFUYIs8isd3xx+
# CdZ0GGyUmIUQTZ4DmpQAl6Bz/Bv5aSExDr8A2YqZR9Ja+xlBiOhGUjhNEKWWeye0
# l6nKC6SOqnZdkTLo2MElhuYc5DeYF4UqTXJjkSlE9F3WmhSg3P26eUlYeYe9IWbA
# cL25L4UCtXqNKpdenoPCERM2ontLtkfo3aob6k6S7SYZmg9OYmK0gZEIHwUnLs8j
# 3CF0T4r6pTNna/eJCygRtYPw1WLoo6N85tLJPVkAQesrcMpB72gII29RzWsM5IPq
# JYOFsNTEgXgiiE9VB5uqnm1te7ro0v0nBkGiGW0rHboPawVinrXly3R/thhJPolR
# gKjX1z9PuCd1dQeYCKrmWyW+F1W2gv6cYjYTSRIP6IU4+pmr/lD1LN7DBbxS5rY6
# mu73J/ixcLeQPvgGe1K8Yti6fwhgise8zbpXeXUlZ80LOZMyvni7cI0v6nxo7PCf
# 7o3bIzr2FTwWvkiDgL9Dda1TXJKjfkB0bvsLOq+UCSZboKxK0S1ewkbh7I8t0chS
# gaQn6VTEKHzCWXo3TnBnerH8o568oHC6O+LTGG7lX+Nkc7J+R9bbGuYAXtlllCsc
# FCsTjDAiVjSLd5OOcVlesmMCAwEAAQ==
# -----END PUBLIC KEY-----

# %%
# !python ./RsaCtfTool/RsaCtfTool.py --createpub -n ... -e 100003 --decrypt ... --private
# Out:
# -----BEGIN PUBLIC KEY-----
# MIICIjANBgkqhkiG9w0BAQEFAAOCAg8AMIICCgKCAgEAznbaCRJdXqZeSYzwPwwi
# RQSQLS5j88sz+Y+UGfi4qYRlHl1kOMM1rM/N7PLbt61eQ1VtiwTFUYIs8isd3xx+
# CdZ0GGyUmIUQTZ4DmpQAl6Bz/Bv5aSExDr8A2YqZR9Ja+xlBiOhGUjhNEKWWeye0
# l6nKC6SOqnZdkTLo2MElhuYc5DeYF4UqTXJjkSlE9F3WmhSg3P26eUlYeYe9IWbA
# cL25L4UCtXqNKpdenoPCERM2ontLtkfo3aob6k6S7SYZmg9OYmK0gZEIHwUnLs8j
# 3CF0T4r6pTNna/eJCygRtYPw1WLoo6N85tLJPVkAQesrcMpB72gII29RzWsM5IPq
# JYOFsNTEgXgiiE9VB5uqnm1te7ro0v0nBkGiGW0rHboPawVinrXly3R/thhJPolR
# gKjX1z9PuCd1dQeYCKrmWyW+F1W2gv6cYjYTSRIP6IU4+pmr/lD1LN7DBbxS5rY6
# mu73J/ixcLeQPvgGe1K8Yti6fwhgise8zbpXeXUlZ80LOZMyvni7cI0v6nxo7PCf
# 7o3bIzr2FTwWvkiDgL9Dda1TXJKjfkB0bvsLOq+UCSZboKxK0S1ewkbh7I8t0chS
# gaQn6VTEKHzCWXo3TnBnerH8o568oHC6O+LTGG7lX+Nkc7J+R9bbGuYAXtlllCsc
# FCsTjDAiVjSLd5OOcVlesmMCAwGGow==
# -----END PUBLIC KEY-----

# %%
# !python ./RsaCtfTool/RsaCtfTool.py -n "..." -e "65537,100003" --decrypt "...,..." --attack same_n_huge_e --private
# Out:
# ['/tmp/tmpqtw1_9xg', '/tmp/tmpelzlrvb_']
# [*] Multikey mode using keys: /tmp/tmpqtw1_9xg, /tmp/tmpelzlrvb_
# [*] Performing same_n_huge_e attack.
#
# Results for /tmp/tmpqtw1_9xg,/tmp/tmpelzlrvb_:
# Sorry, cracking failed.
#
# Decrypted data :
# HEX : 0x434e537b3757305f433150483372373358375f573131315f387233344b5f7235343f215f37396631376236643963303766623135346336646364623932616230343761377d
# INT (big endian) : 3875887588536356901596929564759958455951214875531047382463572000920965409073193460640339896425734472404718239662658698843766442802023985086694356729444811227095185277
# INT (little endian) : 7210719507013531941328978813088820223442311144241997581881155079551839816793232524010852166057367801833982231246485901409664990974084673548214025691866486598542773827
# utf-8 : CNS{7W0_C1PH3r73X7_W111_8r34K_r54?!_79f17b6d9c07fb154c6dcdb92ab047a7}
# STR : b'CNS{7W0_C1PH3r73X7_W111_8r34K_r54?!_79f17b6d9c07fb154c6dcdb92ab047a7}'
#
# [*] Testing key /tmp/tmpqtw1_9xg.
# Sorry, cracking failed.
# ...

# %% [markdown]
# ### Decrypt

# %%
# !python ./RsaCtfTool/RsaCtfTool.py --publickey "*.pub" --decrypt "...,..." --attack common_modulus_related_message --private
# Out:
# ['key2.pub', 'key1.pub']
# [*] Multikey mode using keys: key2.pub, key1.pub
# [*] Performing common_modulus_related_message attack.
# Traceback (most recent call last):
#   File "/content/./RsaCtfTool/RsaCtfTool.py", line 588, in <module>
#     main()
#   File "/content/./RsaCtfTool/RsaCtfTool.py", line 580, in main
#     args = run_attacks(args, logger)
#   File "/content/./RsaCtfTool/RsaCtfTool.py", line 251, in run_attacks
#     found = attackobj.attack_multiple_keys(args.publickey, selected_attacks)
#   File "/content/RsaCtfTool/lib/rsa_attack.py", line 222, in attack_multiple_keys
#     self.priv_key, decrypted = attack_module.attack(
#   File "/content/RsaCtfTool/attacks/multi_keys/common_modulus_related_message.py", line 34, in attack
#     plains.extend(
#   File "/content/RsaCtfTool/attacks/multi_keys/common_modulus_related_message.py", line 35, in <genexpr>
#     self.common_modulus_related_message_attack(c1, c2, k1, k2)
# ...

# %% [markdown]
# ## (c) Eve

# %%
n = [...,
     ...,
     ...,
     ...,
     ...,
     ...,
     ...]
e = 7
c = [...,
     ...,
     ...,
     ...,
     ...,
     ...,
     ...]

# %%
import functools
from Crypto.Util.number import long_to_bytes

def CRT(n, c):
    N = 1
    x = 0
    for i in range(len(n)):
      N *= n[i]
    for i in range(len(n)):
      b = N // n[i]
      b_prime = gmpy2.invert(b, n[i])
      x += c[i] * b * b_prime
      x %= N
    return x

m_decrypt = gmpy2.iroot(CRT(n, c), e)[0]
long_to_bytes(m_decrypt)
# Out:
# b'Broadcast attack on RSA seems fun right? Note that if plaintext is short and public key e is small, you could try to computing the e-th root over the integer :D Anyway, here is the flag: CNS{CH1N353_r3M41ND3r_r3P347_8r04DC457_4774CK_edc38122a288aa9922617b5a6a08ac61}'

# %% [markdown]
# ## (d) admin

# %%
# !python ./RsaCtfTool/RsaCtfTool.py -n ... -e ... --decrypt ... --private --attack wiener
# Out:
# ['/tmp/tmpohykn1km']
#
# [*] Testing key /tmp/tmpohykn1km.
# [*] Performing wiener attack on /tmp/tmpohykn1km.
#  16% 290/1799 [00:00<00:00, 180708.39it/s]
# [*] Attack success with wiener method !
#
# Results for /tmp/tmpohykn1km:
#
# Private key :
# -----BEGIN RSA PRIVATE KEY-----
# MIIH5AIBAAKCAgEAsXkDmbhjEblaSCE48pjOUC5RIbVFs43GOp7MmJVGwKLKiOjY
# A9NaQPGST7R2J31KKoFDD34L5p9mEUSQgYeHv0qtnTqe9sNZ87/f1rR6sMFEM3s2
# i4WAl63EO9jANdOmNJpncTVvwaRBX+1L/6Fo4mE1HHwAmNPsYuLRRDMMN3dVH5my
# uKY5uII9UBw/rOXmsoaQVpiTlZKJJNDI6xGCSYf3PUacxl4CehZd+InPhwd0Ib47
# QRK4r+LSKy5FmuShc5FTmTNdkrFQcZ1ZQZHejPBIr0C/Y00Wdg923UdbhcFicsj8
# cnXsvM5a/aEQ5F/Nd/DAM1u36lbsq98NB2du3V4k0veMB0Ku6dcsDSP6EMO2f7/+
# Y1bPbLx+jn4TwUXj8EHeLEWUBg90iupey1fDX4gCVumfv9ZsAc9oZLuwVWD3lSuI
# ss8N5DhhQskbmTbQMnX9txX50zX8yzPG8iaZywVaVYvgAgQG+pXqq2qWEZwVmILC
# ia8aT7U+7SGmRHzCOvIgTzpUpZmwucIUp9HrRLCncAnakTArtJqXRvNIgCLkGSRq
# uPw5+swke2XCMjPGfEKuyb/iyVpn3Fale4IBPTrMD9Y/a7xApnieqtB2EP/T5EHG
# ...
